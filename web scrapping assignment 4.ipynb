# %% [markdown]
# • Read all the problem statements, notes carefully and scrape the required data using any web scraping tool of
# your choice.
# • You have to handle commonly occurring EXCEPTIONS by using exception handling programing. To get
# information about selenium Exceptions. You may visit following links:
# 1. https://selenium-python.readthedocs.io/api.html
# 2. https://www.guru99.com/exception-handling-selenium.html
# 3. https://stackoverflow.com/questions/38022658/selenium-python-handling-no-such-elementexception/38023345
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia. Url
# = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos You need to find following details: A)
# Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
import re


import selenium
import pandas as pd
from selenium import webdriver


from bs4 import BeautifulSoup
import requests


import time
from selenium.webdriver.common.by import By


from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException

from selenium.webdriver.support.ui import WebDriverWait

# %%
driver=webdriver.Edge()



driver.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

# %%
Rank = []
Name = []
Artist = []
Date = []
Views = []

# %%
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]"):
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append("-")
        

try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]"):
        Name.append(i.text)
except NoSuchElementException:
    Name.append("-")
        

try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]"):
        Artist.append(i.text)
except NoSuchElementException:
    Artist.append("-")
        

try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]"):
        Date.append(i.text)
except NoSuchElementException:
    Date.append("-")
        

try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]"):
        Views.append(i.text)
except NoSuchElementException:
    Views.append("-")

# %%
Wiki = pd.DataFrame({})
Wiki['Rank'] = Rank
Wiki['Name'] = Name
Wiki['Artist'] = Artist
Wiki['Upload Date'] = Date
Wiki['Views (in Billions)'] = Views


Wiki.Name = Wiki.Name.apply(lambda x:x[:-4].strip('"'))
Wiki
# Out:
#    Rank                                       Name  \
# 0    1.                           Baby Shark Dance
# 1    2.                                  Despacito
# 2    3.                       Johny Johny Yes Papa
# 3    4.                                  Bath Song
# 4    5.                               Shape of You
# 5    6.                              See You Again
# 6    7.                          Wheels on the Bus
# 7    8.                Phonics Song with Two Words
# 8    9.                                Uptown Funk
# 9   10.  Learning Colors – Colorful Eggs on a Farm
# 10  11.                              Gangnam Style
# 11  12.   Masha and the Bear – Recipe for Disaster
# 12  13.                             Dame Tu Cosita
# 13  14.                                     Axel F
# 14  15.                                      Sugar
# 15  16.                             Counting Stars
# 16  17.                                       Roar
# 17  18.                        Baa Baa Black Sheep
# 18  19.           Waka Waka (This Time for Africa)
# 19  20.                                      Sorry
# 20  21.                             Lakdi Ki Kathi
# 21  22.                          Thinking Out Loud
# 22  23.                                 Dark Horse
# 23  24.          Humpty the train on a fruits ride
# 24  25.                                    Perfect
# 25  26.                                 Let Her Go
# 26  27.                                      Faded
# 27  28.                             Girls Like You
# 28  29.                      Shree Hanuman Chalisa
# 29  30.                                    Lean On
# 30   1.                           Baby Shark Dance
# 31   2.                                  Despacito
# 32   3.                       Johny Johny Yes Papa
# 33   4.                                  Bath Song
# 34   5.                               Shape of You
# 35   6.                              See You Again
# 36   7.                          Wheels on the Bus
# 37   8.                Phonics Song with Two Words
# 38   9.                                Uptown Funk
# 39  10.  Learning Colors – Colorful Eggs on a Farm
# 40  11.                              Gangnam Style
# 41  12.   Masha and the Bear – Recipe for Disaster
# 42  13.                             Dame Tu Cosita
# 43  14.                                     Axel F
# 44  15.                                      Sugar
# 45  16.                             Counting Stars
# 46  17.                                       Roar
# 47  18.                        Baa Baa Black Sheep
# 48  19.           Waka Waka (This Time for Africa)
# 49  20.                                      Sorry
# 50  21.                             Lakdi Ki Kathi
# 51  22.                          Thinking Out Loud
# 52  23.                                 Dark Horse
# 53  24.          Humpty the train on a fruits ride
# 54  25.                                    Perfect
# 55  26.                                 Let Her Go
# 56  27.                                      Faded
# 57  28.                             Girls Like You
# 58  29.                      Shree Hanuman Chalisa
# 59  30.                                    Lean On
#
#                                                Artist        Upload Date  \
# 0         Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016
# 1                                          Luis Fonsi   January 12, 2017
# 2   LooLoo Kids - Nursery Rhymes and Children's Songs    October 8, 2016
# 3                          Cocomelon - Nursery Rhymes        May 2, 2018
# 4                                          Ed Sheeran   January 30, 2017
# 5                                         Wiz Khalifa      April 6, 2015
# 6                          Cocomelon - Nursery Rhymes       May 24, 2018
# 7               ChuChu TV Nursery Rhymes & Kids Songs      March 6, 2014
# 8                                         Mark Ronson  November 19, 2014
# 9                                         Miroshka TV  February 27, 2018
# 10                                        officialpsy      July 15, 2012
# 11                                         Get Movies   January 31, 2012
# 12                                      Ultra Records      April 5, 2018
# 13                                         Crazy Frog      June 16, 2009
# 14                                           Maroon 5   January 14, 2015
# 15                                        OneRepublic       May 31, 2013
# 16                                         Katy Perry  September 5, 2013
# 17                         Cocomelon - Nursery Rhymes      June 25, 2018
# 18                                            Shakira       June 4, 2010
# 19                                      Justin Bieber   October 22, 2015
# 20                                       Jingle Toons      June 14, 2018
# 21                                         Ed Sheeran    October 7, 2014
# 22                                         Katy Perry  February 20, 2014
# 23      Kiddiestv Hindi - Nursery Rhymes & Kids Songs   January 26, 2018
# 24                                         Ed Sheeran   November 9, 2017
# 25                                          Passenger      July 25, 2012
# 26                                        Alan Walker   December 3, 2015
# 27                                           Maroon 5       May 31, 2018
# 28                              T-Series Bhakti Sagar       May 10, 2011
# 29                               Major Lazer Official     March 22, 2015
# 30        Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016
# 31                                         Luis Fonsi   January 12, 2017
# 32  LooLoo Kids - Nursery Rhymes and Children's Songs    October 8, 2016
# 33                         Cocomelon - Nursery Rhymes        May 2, 2018
# 34                                         Ed Sheeran   January 30, 2017
# 35                                        Wiz Khalifa      April 6, 2015
# 36                         Cocomelon - Nursery Rhymes       May 24, 2018
# 37              ChuChu TV Nursery Rhymes & Kids Songs      March 6, 2014
# 38                                        Mark Ronson  November 19, 2014
# 39                                        Miroshka TV  February 27, 2018
# 40                                        officialpsy      July 15, 2012
# 41                                         Get Movies   January 31, 2012
# 42                                      Ultra Records      April 5, 2018
# 43                                         Crazy Frog      June 16, 2009
# 44                                           Maroon 5   January 14, 2015
# 45                                        OneRepublic       May 31, 2013
# 46                                         Katy Perry  September 5, 2013
# 47                         Cocomelon - Nursery Rhymes      June 25, 2018
# 48                                            Shakira       June 4, 2010
# 49                                      Justin Bieber   October 22, 2015
# 50                                       Jingle Toons      June 14, 2018
# 51                                         Ed Sheeran    October 7, 2014
# 52                                         Katy Perry  February 20, 2014
# 53      Kiddiestv Hindi - Nursery Rhymes & Kids Songs   January 26, 2018
# 54                                         Ed Sheeran   November 9, 2017
# 55                                          Passenger      July 25, 2012
# 56                                        Alan Walker   December 3, 2015
# 57                                           Maroon 5       May 31, 2018
# 58                              T-Series Bhakti Sagar       May 10, 2011
# 59                               Major Lazer Official     March 22, 2015
#
#    Views (in Billions)
# 0                13.48
# 1                 8.28
# 2                 6.82
# 3                 6.45
# 4                 6.11
# 5                 6.05
# 6                 5.62
# 7                 5.52
# 8                 5.05
# 9                 4.99
# 10                4.92
# 11                4.56
# 12                4.46
# 13                4.09
# 14                3.95
# 15                3.89
# 16                3.89
# 17                3.80
# 18                3.75
# 19                3.72
# 20                3.71
# 21                3.67
# 22                3.60
# 23                3.58
# 24                3.56
# 25                3.53
# 26                3.53
# 27                3.50
# 28                3.48
# 29                3.48
# 30               13.48
# 31                8.28
# 32                6.82
# 33                6.45
# 34                6.11
# 35                6.05
# 36                5.62
# 37                5.52
# 38                5.05
# 39                4.99
# 40                4.92
# 41                4.56
# 42                4.46
# 43                4.09
# 44                3.95
# 45                3.89
# 46                3.89
# 47                3.80
# 48                3.75
# 49                3.72
# 50                3.71
# 51                3.67
# 52                3.60
# 53                3.58
# 54                3.56
# 55                3.53
# 56                3.53
# 57                3.50
# 58                3.48
# 59                3.48

# %%
print(len(Rank),
len(Name),
len(Artist),
len(Date),
len(Views))
# Out:
# 60 60 60 60 60

# %%
driver.close()

# %% [markdown]
# 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Series
# B) Place
# C) Date
# D) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
driver=webdriver.Edge()

# %%
url=('https://www.bcci.tv/')
driver.get(url)

# %%
btn=driver.find_element(By.XPATH,"//div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']/div/ul/li/a")
driver.get(btn.get_attribute("href"))
time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24460\1938746527.py in <module>
# ----> 1 btn=driver.find_element(By.XPATH,"//div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']/div/ul/li/a")
#       2 driver.get(btn.get_attribute("href"))
#       3 time.sleep(3)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     736             value = f'[name="{value}"]'
#     737
# --> 738         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     739
#     740     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     342         response = self.command_executor.execute(driver_command, params)
#     343         if response:
# --> 344             self.error_handler.check_response(response)
#     345             response["value"] = self._unwrap_value(response.get("value", None))
#     346             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']/div/ul/li/a"}
#   (Session info: MicrosoftEdge=118.0.2088.46); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF763F28952+63554]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EB2472+257794]
# 	(No symbol) [0x00007FF763C91139]
# 	(No symbol) [0x00007FF763CD6098]
# 	(No symbol) [0x00007FF763CD61A9]
# 	(No symbol) [0x00007FF763D0C717]
# 	(No symbol) [0x00007FF763CF4C3F]
# 	(No symbol) [0x00007FF763CCB541]
# 	(No symbol) [0x00007FF763D0A21B]
# 	(No symbol) [0x00007FF763CF49D3]
# 	(No symbol) [0x00007FF763CCA574]
# 	(No symbol) [0x00007FF763CC9C40]
# 	(No symbol) [0x00007FF763CCACF4]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF7640E8BD9+1121529]
# 	(No symbol) [0x00007FF763D37BB6]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF763E01DBA+33914]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF763DFA759+3609]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF7640E7C54+1117556]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EBC728+299448]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EB74B4+278340]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EB75E2+278642]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EAA9A1+226353]
# 	BaseThreadInitThunk [0x00007FFE4A15257D+29]
# 	RtlUserThreadStart [0x00007FFE4AF2AA68+40]

# %%
# creating empty lists for scraping the data
Match_Title = []
Series = []
Place = []
Date = []
Time = []

# %%
for i in driver.find_elements(By.XPATH,"//div[@class='fixture__format-strip']/span[@class='u-unskewed-text fixture__format']"):
    Match_Title.append(i.text)
    
for i in driver.find_elements(By.XPATH,"//div[@class='fixture__format-strip']/span[@class='u-unskewed-text fixture__tournament-label u-truncated']"):
    Series.append(i.text)
    
for i in driver.find_elements(By.XPATH,"//div[@class='fixture__description u-unskewed-text']/p/span"):
    Place.append(i.text)
        
for i in driver.find_elements(By.XPATH,"//span[@class='fixture__datetime tablet-only']/strong[1]"):
    Date.append(i.text.replace('\n',' '))

date=[i.split(' ',3)[:3] for i in Date]
date=[' '.join(i) for i in date]
Time=[i.split(' ',3)[-1] for i in Date]

# creating data frame
fixture=pd.DataFrame({'Match Title': Match_Title,
                          "Series": Series,
                          "Place": Place,
                          "Date": date,
                          "Time": Time})
fixture
# Out:
# Empty DataFrame
# Columns: [Match Title, Series, Place, Date, Time]
# Index: []

# %%
len(url)
# Out:
# 20

# %% [markdown]
# # question 3 : Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details: A) Rank
# B) State
# C) GSDP(18-19)- at current prices
# D) GSDP(19-20)- at current prices
# E) Share(18-19)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code

# %%
driver=webdriver.Edge()

# %%
url = ("https://statisticstimes.com/")
driver.get(url)

# %%
 
driver.find_element(By.XPATH,"//div[@class='navbar']/div[2]/button").click()


driver.find_element(By.XPATH,"//div[@class='dropdown-content']/a[3]").click()
time.sleep(3)


GDP = driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[2]/ul/li[1]/a").click()
time.sleep(3)

# %%
Rank = []
State = []
GSDP1 = []
GSDP2 = []
Share = []
GDP_billion = []

# %%
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[1]"):
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append("_")
    

try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[2]"):
        State.append(i.text)
except NoSuchElementException:
    State.append("_")
    

try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[3]"):
        GSDP1.append(i.text)
except NoSuchElementException:
    GSDP1.append("_")
    

try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[4]"):
        GSDP2.append(i.text)
except NoSuchElementException:
    GSDP2.append("_")
    

try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[5]"):
        Share.append(i.text)
except NoSuchElementException:
    Share.append("_")
    

try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[6]"):
        GDP_billion.append(i.text)
except NoSuchElementException:
    GDP_billion.append("_")
    
    

GDP = pd.DataFrame({})
GDP['Rank'] = Rank
GDP['State'] = State
GDP['GSDP at current price (19-20)'] = GSDP1
GDP['GSDP at current price (18-19)'] = GSDP2
GDP['Share (18-19)'] = Share
GDP['GDP($ billion)'] = GDP_billion
GDP
# Out:
#    Rank                      State GSDP at current price (19-20)  \
# 0     1                Maharashtra                             -
# 1     2                 Tamil Nadu                     1,845,853
# 2     3              Uttar Pradesh                     1,687,818
# 3     4                    Gujarat                             -
# 4     5                  Karnataka                     1,631,977
# ..  ...                        ...                           ...
# 61   29                     Sikkim                        28,391
# 62   30                   Nagaland                             -
# 63   31          Arunachal Pradesh                             -
# 64   32                    Mizoram                        24,424
# 65   33  Andaman & Nicobar Islands                             -
#
#    GSDP at current price (18-19) Share (18-19) GDP($ billion)
# 0                      2,632,792        13.94%        399.921
# 1                      1,630,208         8.63%        247.629
# 2                      1,584,764         8.39%        240.726
# 3                      1,502,899         7.96%        228.290
# 4                      1,493,127         7.91%        226.806
# ..                           ...           ...            ...
# 61                        25,141         0.15%         17,060
# 62                        24,534         0.15%              -
# 63                        22,488         0.13%              -
# 64                        20,947         0.13%         17,797
# 65                             -             -              -
#
# [66 rows x 6 columns]

# %% [markdown]
# # Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
driver=webdriver.Edge()

# %%
url = ("https://github.com/")
driver.get(url)

# %%
explore = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button").click()


trend_url = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/div[3]/ul/li[2]/a").Click()
urls = trend_url.get_attribute("href")
driver.get(urls)
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24460\3302206687.py in <module>
# ----> 1 explore = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button").click()
#       2
#       3 # selecting trending option
#       4 trend_url = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/div[3]/ul/li[2]/a").Click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      91     def click(self) -> None:
#      92         """Clicks the element."""
# ---> 93         self._execute(Command.CLICK_ELEMENT)
#      94
#      95     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     392             params = {}
#     393         params["id"] = self._id
# --> 394         return self._parent.execute(command, params)
#     395
#     396     def find_element(self, by=By.ID, value=None) -> WebElement:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     342         response = self.command_executor.execute(driver_command, params)
#     343         if response:
# --> 344             self.error_handler.check_response(response)
#     345             response["value"] = self._unwrap_value(response.get("value", None))
#     346             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: MicrosoftEdge=118.0.2088.46)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF763F28952+63554]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EB2472+257794]
# 	(No symbol) [0x00007FF763C90FED]
# 	(No symbol) [0x00007FF763CD7433]
# 	(No symbol) [0x00007FF763CCBC43]
# 	(No symbol) [0x00007FF763CF4BFA]
# 	(No symbol) [0x00007FF763CCB541]
# 	(No symbol) [0x00007FF763CCB3ED]
# 	(No symbol) [0x00007FF763CF4F20]
# 	(No symbol) [0x00007FF763CCB541]
# 	(No symbol) [0x00007FF763D0A21B]
# 	(No symbol) [0x00007FF763CF49D3]
# 	(No symbol) [0x00007FF763CCA574]
# 	(No symbol) [0x00007FF763CC9C40]
# 	(No symbol) [0x00007FF763CCACF4]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF7640E8BD9+1121529]
# 	(No symbol) [0x00007FF763D37BB6]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF763E01DBA+33914]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF763DFA759+3609]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF7640E7C54+1117556]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EBC728+299448]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EB74B4+278340]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EB75E2+278642]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EAA9A1+226353]
# 	BaseThreadInitThunk [0x00007FFE4A15257D+29]
# 	RtlUserThreadStart [0x00007FFE4AF2AA68+40]

# %%
URLs = []
repository_title = []
Description = []
Contributors = []
Language = []
lang = []


repository = driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']//a")
for i in repository:
    URLs.append(i.get_attribute("href"))
    

title = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']")
for i in title:
    repository_title.append(i.text)
    

for i in URLs:
    driver.get(i)
    time.sleep(5)
    
    
    try:
        desc = driver.find_element_by_xpath("//p[@class='f4 mt-3']")
        Description.append(desc.text)
    except NoSuchElementException:
        Description.append('-')
        
        
    
    try:
        contributor = driver.find_element_by_xpath("//*[contains(text(),'    Contributors ')]")
        Contributors.append(contributor.text.replace('Contributors',''))
    except NoSuchElementException:
        Contributors.append('-')
    
    
    
    try:
        for i in driver.find_elements_by_xpath("//ul[@class= 'list-style-none']//li//span[1]"):
            lang.append(i.text)
        Language.append(lang)
    except NoSuchElementException:
        Language.append('-')
        
        

Github = pd.DataFrame({})
Github['Repository Title'] = repository_title
Github['Repository Description'] = Description
Github['Contributors Count'] = Contributors
Github['Language Used'] = Language
Github

# %%
driver.close()

# %% [markdown]
# # 5. Scrape the details of top 100 songs on billiboard.com. Url = https:/www.billboard.com/ You have to find the
# following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
#  Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver=webdriver.Edge()

# %%
url = ("https:/www.billboard.com/")
driver.get(url)

# %%
charts=driver.find_element(By.XPATH,"//a[@class='header__main-link header__main-link--charts']").click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24460\728709808.py in <module>
# ----> 1 charts=driver.find_element(By.XPATH,"//a[@class='header__main-link header__main-link--charts']").click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     736             value = f'[name="{value}"]'
#     737
# --> 738         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     739
#     740     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     342         response = self.command_executor.execute(driver_command, params)
#     343         if response:
# --> 344             self.error_handler.check_response(response)
#     345             response["value"] = self._unwrap_value(response.get("value", None))
#     346             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//a[@class='header__main-link header__main-link--charts']"}
#   (Session info: MicrosoftEdge=118.0.2088.46); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF763F28952+63554]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EB2472+257794]
# 	(No symbol) [0x00007FF763C91139]
# 	(No symbol) [0x00007FF763CD6098]
# 	(No symbol) [0x00007FF763CD61A9]
# 	(No symbol) [0x00007FF763D0C717]
# 	(No symbol) [0x00007FF763CF4C3F]
# 	(No symbol) [0x00007FF763CCB541]
# 	(No symbol) [0x00007FF763D0A21B]
# 	(No symbol) [0x00007FF763CF49D3]
# 	(No symbol) [0x00007FF763CCA574]
# 	(No symbol) [0x00007FF763CC9C40]
# 	(No symbol) [0x00007FF763CCACF4]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF7640E8BD9+1121529]
# 	(No symbol) [0x00007FF763D37BB6]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF763E01DBA+33914]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF763DFA759+3609]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF7640E7C54+1117556]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EBC728+299448]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EB74B4+278340]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EB75E2+278642]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EAA9A1+226353]
# 	BaseThreadInitThunk [0x00007FFE4A15257D+29]
# 	RtlUserThreadStart [0x00007FFE4AF2AA68+40]

# %%
Song_Name = []
Artist_Name =[]
Last_week_rank = []
Peak_rank = []
Weeks_on_board = []


urls = driver.find_element(By.XPATH,"//li[@class='header__submenu__list__element']//a")
page_url = urls.get_attribute("href")
driver.get(page_url)
time.sleep(4)


for i in driver.find_elements(By.XPATH,"//span[@class='chart-element__information__song text--truncate color--primary']"):
    Song_Name.append(i.text)
    

for i in driver.find_elements(By.XPATH,"//span[@class='chart-element__information__artist text--truncate color--secondary']"):
    Artist_Name.append(i.text)
    

for i in driver.find_elements(By.XPATH,"//div[@class='chart-element__meta text--center color--secondary text--last']"):
    Last_week_rank.append(i.text)
    


for i in driver.find_elements(By.XPATH,"//div[@class='chart-element__meta text--center color--secondary text--peak']"):
    Peak_rank.append(i.text)       
    
    

for i in driver.find_elements(By.XPATH,"//div[@class='chart-element__meta text--center color--secondary text--week']"):
    Weeks_on_board.append(i.text)
    
    

billiboard = pd.DataFrame({})
billiboard['Name'] = Song_Name
billiboard['Artist'] = Artist_Name
billiboard['Last Week Rank'] = Last_week_rank
billiboard['Peak Rank'] = Peak_rank
billiboard['Weeks on board'] = Weeks_on_board
billiboard

# %% [markdown]
# # 6. Scrape the details of Highest selling novels.
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre
#  Url - https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare

# %%
driver=webdriver.Edge()

# %%
url = ("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")
driver.get(url)

# %%
Book_name = []
Author_name = []
Volumes_sold = []
Publisher = []
Genre = []

# %%
for i in driver.find_elements(By.XPATH,"//tbody//tr//td[2]"):
    Book_name.append(i.text)

    

for i in driver.find_elements(By.XPATH,"//tbody//tr//td[3]"):
    try:
        if i.text == '0' : raise NoSuchElementException
        Author_name.append(i.text)
    except NoSuchElementException:
        Author_name.append('-')
time.sleep(3)



for i in driver.find_elements(By.XPATH,"//tbody//tr//td[4]"):
    Volumes_sold.append(i.text)
    

for i in driver.find_elements(By.XPATH,"//tbody//tr//td[5]"):
    Publisher.append(i.text)
    
    

for i in driver.find_elements(By.XPATH,"//tbody//tr//td[6]"):
    Genre.append(i.text)    
    

Novels = pd.DataFrame({})
Novels['Book Name'] = Book_name
Novels['Author'] = Author_name
Novels['Volume sold'] = Volumes_sold
Novels['Publisher'] = Publisher
Novels['Genre'] = Genre
Novels
# Out:
#                                             Book Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold        Publisher                        Genre
# 0    5,094,805       Transworld  Crime, Thriller & Adventure
# 1    4,475,152       Bloomsbury           Children's Fiction
# 2    4,200,654       Bloomsbury           Children's Fiction
# 3    4,179,479       Bloomsbury           Children's Fiction
# 4    3,758,936     Random House              Romance & Sagas
# ..         ...              ...                          ...
# 95     807,311     Random House   General & Literary Fiction
# 96     794,201          Penguin        Food & Drink: General
# 97     792,187  Scholastic Ltd.          Young Adult Fiction
# 98     791,507            Orion           Biography: General
# 99     791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# # Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/ You have
# to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
driver=webdriver.Edge()

# %%
url = ("https://www.imdb.com/list/ls095964455/")
driver.get(url)

# %%
Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []


for i in driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/a"):
    Name.append(i.text)
    
    

for i in driver.find_elements(By.XPATH,"//span[@class='lister-item-year text-muted unbold']"):
    Year_span.append(i.text)
    
    

for i in driver.find_elements(By.XPATH,"//span[@class='genre']"):
    Genre.append(i.text)
    
    

for i in driver.find_elements(By.XPATH,"//span[@class='runtime']"):
    Run_time.append(i.text)
    
    

for i in driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']//span[2]"):
    Ratings.append(i.text)
    
    

for i in driver.find_elements(By.XPATH,"//div[@class='lister-item-content']//p[4]/span[2]"):
    Votes.append(i.text) 
    
    

TV_Series = pd.DataFrame({})
TV_Series['Name'] = Name
TV_Series['Year Span'] = Year_span
TV_Series['Genre'] = Genre
TV_Series['Run Time'] = Run_time
TV_Series['Ratings'] = Ratings
TV_Series['Votes'] = Votes
TV_Series
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things  (2016–2025)    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  2,213,852
# 1    51 min     8.7  1,283,566
# 2    44 min     8.1  1,050,582
# 3    60 min     7.5    308,672
# 4    43 min     7.6    267,613
# ..      ...     ...        ...
# 95   42 min     7.5     52,969
# 96   50 min     7.8     65,033
# 97   42 min     8.1    211,961
# 98   45 min       7     44,119
# 99  572 min     8.6    270,467
#
# [100 rows x 6 columns]

# %% [markdown]
# # 8. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/ You
# have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute G) Year
#  Note: - from the home page you have to go to the Show All Dataset page through code.

# %%
driver=webdriver.Edge()

# %%
url = ("https://archive.ics.uci.edu")
driver.get(url)

# %%
Dataset_name = []
Data_type = []
Task = []
Attribute_type = []
No_of_instances = []
No_of_attributes = []
Year = []

# %%
viewall_dataset = driver.find_element(By.XPATH,"//tbody[1]//tr/td[2]/span[2]/a")
page_url = viewall_dataset.get_attribute("href")
driver.get(page_url)
time.sleep(3)

view_list = driver.find_element(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[1]/tbody/tr/td[2]/p/a")
list_url = view_list.get_attribute("href")
driver.get(list_url)
time.sleep(3)

dataset_url = driver.find_elements(By.XPATH,"//p[@class='normal']//b/a")

urls = []
for i in dataset_url:
    urls.append(i.get_attribute("href"))

Dataset_name = []
Data_type = []
Task = []
Attribute_type = []
No_of_instances = []
No_of_attributes = []
Year = []

for i in urls:
    driver.get(i)
    time.sleep(3)
    
    
    
    try:
        dataset_name = driver.find_element(By.XPATH,"//span[@class='heading']")
        Dataset_name.append(dataset_name.text)
    except NoSuchElementException:
        Dataset_name.append('-')
    time.sleep(3)
    
    
    
    
    try:
        data_type = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr/td[2]")
        if data_type.text == "N/A": raise NoSuchElementException
        Data_type.append(data_type.text)
    except NoSuchElementException:
        Data_type.append('-')
    time.sleep(3)
    
    
    
    try:
        task = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[3]/td[2]")
        if task.text == "N/A": raise NoSuchElementException
        Task.append(task.text)
    except NoSuchElementException:
        Task.append('-')
    time.sleep(3)
    
    
    
    
    try:
        attribute_type = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[2]")
        if attribute_type.text == "N/A": raise NoSuchElementException
        Attribute_type.append(attribute_type.text)
    except NoSuchElementException:
        Attribute_type.append('-')
    time.sleep(3)
    
    
    
    
    try:
        instances = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr/td[4]")
        if instances.text == "N/A": raise NoSuchElementException
        No_of_instances.append(instances.text)
    except NoSuchElementException:
        No_of_instances.append('-')
    time.sleep(3)
    
    
    
    
    try:
        attribute = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[4]")
        if attribute.text == "N/A": raise NoSuchElementException
        No_of_attributes.append(attribute.text)
    except NoSuchElementException:
        No_of_attributes.append('-')
    time.sleep(3)
    
    
    
    try:
        year = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[6]")
        if year.text == "N/A": raise NoSuchElementException
        Year.append(year.text[:4])
    except NoSuchElementException:
        Year.append('-')
    time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24460\2607347131.py in <module>
# ----> 1 viewall_dataset = driver.find_element(By.XPATH,"//tbody[1]//tr/td[2]/span[2]/a")
#       2 page_url = viewall_dataset.get_attribute("href")
#       3 driver.get(page_url)
#       4 time.sleep(3)
#       5 # fetching page urls of all datasets
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     736             value = f'[name="{value}"]'
#     737
# --> 738         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     739
#     740     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     342         response = self.command_executor.execute(driver_command, params)
#     343         if response:
# --> 344             self.error_handler.check_response(response)
#     345             response["value"] = self._unwrap_value(response.get("value", None))
#     346             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//tbody[1]//tr/td[2]/span[2]/a"}
#   (Session info: MicrosoftEdge=118.0.2088.46); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF763F28952+63554]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EB2472+257794]
# 	(No symbol) [0x00007FF763C91139]
# 	(No symbol) [0x00007FF763CD6098]
# 	(No symbol) [0x00007FF763CD61A9]
# 	(No symbol) [0x00007FF763D0C717]
# 	(No symbol) [0x00007FF763CF4C3F]
# 	(No symbol) [0x00007FF763CCB541]
# 	(No symbol) [0x00007FF763D0A21B]
# 	(No symbol) [0x00007FF763CF49D3]
# 	(No symbol) [0x00007FF763CCA574]
# 	(No symbol) [0x00007FF763CC9C40]
# 	(No symbol) [0x00007FF763CCACF4]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF7640E8BD9+1121529]
# 	(No symbol) [0x00007FF763D37BB6]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF763E01DBA+33914]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF763DFA759+3609]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF7640E7C54+1117556]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EBC728+299448]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EB74B4+278340]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EB75E2+278642]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF763EAA9A1+226353]
# 	BaseThreadInitThunk [0x00007FFE4A15257D+29]
# 	RtlUserThreadStart [0x00007FFE4AF2AA68+40]

# %%
ML = pd.DataFrame({})
ML['Data Name'] = Data_name 
ML['Data Type '] = Data_type
ML['Task '] = Task 
ML['Attribute Type '] = Attribute_type 
ML['No of Instance '] = No_of_instances
ML['No of Attributes '] = No_of_attributes 
ML['Year '] = Year 
ML
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24460\1890256917.py in <module>
#       1 ML = pd.DataFrame({})
# ----> 2 ML['Data Name'] = Data_name
#       3 ML['Data Type '] = Data_type
#       4 ML['Task '] = Task
#       5 ML['Attribute Type '] = Attribute_type
#
# NameError: name 'Data_name' is not defined
